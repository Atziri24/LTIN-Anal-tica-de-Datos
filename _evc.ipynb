# %% [markdown]
# # 2024-A LTIN Analítica de Datos

# %% [markdown]
# # Actividad 6
# # Sanchez Salazar Atziri Yoseline
# # 0009-0004-4794-0822

# %%
# Importar las librerias necesarios
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Generar datos de  muestra 
np.random.seed (42)
datos = np.random.normal(loc=100, scale=15, size=100)

# Crear un DataFrame
df = pd.DataFrame(datos, columns=['Variable_Continua'])

# %%
# Análisis descriptivo
media =df ['Variable_Continua'].mean()
mediana =df ['Variable_Continua'].median()
varianza =df ['Variable_Continua'].var()
desviacion_estandar = df['Variable_Continua'].std()

print(f"Media: {media:.2f}")
print(f"Mediana: {mediana:.2f}")
print(f"Varianza: {varianza:.2f}")
print(f"Desviación Estándar: {desviacion_estandar:.2f}")
# Out:
# Media: 98.44
# Mediana: 98.10
# Varianza: 185.57
# Desviación Estándar: 13.62

# %%
# Visualización - Histograma
plt.figure(figsize=(10,6))
sns.histplot(df['Variable_Continua'],kde=True, bins=30, color='skyblue')
plt.title('Distribucion de la variable Continua')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.axvline(media,color='r', linestyle='--', label=f'Mediana: {media: .2f}')
plt.axvline(mediana,color='r', linestyle='--', label=f'Mediana: {mediana: .2f}')
plt.legend()
plt.grid(True)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='Variable_Continua',color='lightgreen')
plt.title('Diagrama de cajas de la Variable Continua')
plt.title('Variable_Continua')
# Out:
# Text(0.5, 1.0, 'Variable_Continua')

# %%
df.to_csv('datos_variable_continua.csv', index=False)
